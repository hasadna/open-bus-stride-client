# %% [markdown]
# ### Install dependencies
#
# This notebook requires two dependencies which can be installed with the following commands:
#
# Pandas library:
#
# ```
# pip install pandas
# ```
#
# Stride API client library:
#
# ```
# pip install open-bus-stride
# ```

# %%
import pandas as PD
import stride

# %% [markdown]
# ### Find a route to investigave
#
# Because the GTFS data is not available yet, we have to use the GTFS operator_ref and line_ref numbers to find a route

# %%
stride.get('/siri_routes/list', {'operator_refs': 14, 'line_refs': 28153})
# Out:
# [{'id': 684, 'line_ref': 28153, 'operator_ref': 14}]

# %% [markdown]
# We determine that the route id is `684` we can now use that to get the rides for this route

# %% [markdown]
# ### Get rides data
#
# We use the stride iterate method to efficiently iterate over a possibly long list of results.
#
# Behind the scenes it uses the offset/limit parameters so you don't have to worry about it.
#
# By default it limits results to 10,000 which should be enough for most cases, but you can increase this number by passing the limit keyword argument.
#
# We pass on the iterator directly on to Pandas to create a DataFrame.

# %%
df = PD.DataFrame(stride.iterate('/siri_rides/list', {'route_ids': '684'}))
df
# Out:
#            id  siri_route_id          journey_ref scheduled_start_time  \
# 0     1665155            175    2021-11-24-747141  2021-11-24T12:23:00
# 1     1665158            271   2021-11-24-5495747  2021-11-24T12:16:00
# 2     1665164            379  2021-11-24-10493647  2021-11-24T12:20:00
# 3     1665165            394  2021-11-24-57890328  2021-11-24T12:24:00
# 4     1770402           2063   2021-11-25-8432830  2021-11-25T13:00:00
# ...       ...            ...                  ...                  ...
# 9995  1936548            585  2021-11-28-51150312  2021-11-28T12:25:00
# 9996  1936549            636   2021-11-28-1307844  2021-11-28T12:25:00
# 9997  1936550            649    2021-11-28-270897  2021-11-28T12:20:00
# 9998  1936551            687  2021-11-28-45566148  2021-11-28T12:26:00
# 9999  1936552            743   2021-11-28-4644016  2021-11-28T12:20:00
#
#      vehicle_ref updated_first_last_vehicle_locations  \
# 0        9260501     2021-11-28T10:19:23.345742+00:00
# 1        7547069     2021-11-28T10:19:23.324854+00:00
# 2        9004258     2021-11-28T10:19:23.332233+00:00
# 3       67287102     2021-11-28T10:19:23.337973+00:00
# 4        7728769     2021-11-28T10:19:23.226201+00:00
# ...          ...                                  ...
# 9995     7718369                                 None
# 9996     7725269                                 None
# 9997     9008858                                 None
# 9998     9252401                                 None
# 9999     7641969                                 None
#
#       first_vehicle_location_id  last_vehicle_location_id  \
# 0                    91566294.0                92083131.0
# 1                    91566608.0                91719635.0
# 2                    91566738.0                91737939.0
# 3                    91566775.0                91755741.0
# 4                    97225263.0                97554703.0
# ...                         ...                       ...
# 9995                        NaN                       NaN
# 9996                        NaN                       NaN
# 9997                        NaN                       NaN
# 9998                        NaN                       NaN
# 9999                        NaN                       NaN
#
#               updated_duration_minutes  duration_minutes
# 0     2021-11-28T10:19:23.345825+00:00              88.0
# 1     2021-11-28T10:19:23.324927+00:00              27.0
# 2     2021-11-28T10:19:23.332323+00:00              30.0
# 3     2021-11-28T10:19:23.338045+00:00              32.0
# 4     2021-11-28T10:19:23.226271+00:00              52.0
# ...                                ...               ...
# 9995                              None               NaN
# 9996                              None               NaN
# 9997                              None               NaN
# 9998                              None               NaN
# 9999                              None               NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ### Manipulate the data using Pandas
#
# Now we can use Pandas to get some information from this data
#
# First, let's filter out results which don't have a duration (those are most likely recent rides for which we haven't yet calculated the duration)

# %%
df = df[df.duration_minutes.notnull()]
df
# Out:
#            id  siri_route_id          journey_ref scheduled_start_time  \
# 0     1665155            175    2021-11-24-747141  2021-11-24T12:23:00
# 1     1665158            271   2021-11-24-5495747  2021-11-24T12:16:00
# 2     1665164            379  2021-11-24-10493647  2021-11-24T12:20:00
# 3     1665165            394  2021-11-24-57890328  2021-11-24T12:24:00
# 4     1770402           2063   2021-11-25-8432830  2021-11-25T13:00:00
# ...       ...            ...                  ...                  ...
# 9905    96296           2833  2021-11-04-28461975  2021-11-04T15:05:00
# 9906    96297           6203   2021-11-04-9765746  2021-11-04T15:00:00
# 9907    96298           5590  2021-11-04-56458061  2021-11-04T15:05:00
# 9908    96299           3286  2021-11-04-58842185  2021-11-04T15:05:00
# 9909    96300           3040  2021-11-04-43321701  2021-11-04T15:05:00
#
#      vehicle_ref updated_first_last_vehicle_locations  \
# 0        9260501     2021-11-28T10:19:23.345742+00:00
# 1        7547069     2021-11-28T10:19:23.324854+00:00
# 2        9004258     2021-11-28T10:19:23.332233+00:00
# 3       67287102     2021-11-28T10:19:23.337973+00:00
# 4        7728769     2021-11-28T10:19:23.226201+00:00
# ...          ...                                  ...
# 9905     7309952     2021-11-28T12:19:18.690686+00:00
# 9906     7316052     2021-11-28T12:19:18.695185+00:00
# 9907    14915102     2021-11-28T12:19:18.698944+00:00
# 9908     8801187     2021-11-28T12:19:18.702648+00:00
# 9909     8802087     2021-11-28T12:19:18.706144+00:00
#
#       first_vehicle_location_id  last_vehicle_location_id  \
# 0                    91566294.0                92083131.0
# 1                    91566608.0                91719635.0
# 2                    91566738.0                91737939.0
# 3                    91566775.0                91755741.0
# 4                    97225263.0                97554703.0
# ...                         ...                       ...
# 9905                  4845577.0                 4970666.0
# 9906                  4845583.0                 5094015.0
# 9907                  4845628.0                 4977253.0
# 9908                  4845655.0                 5068073.0
# 9909                  4845657.0                 5087663.0
#
#               updated_duration_minutes  duration_minutes
# 0     2021-11-28T10:19:23.345825+00:00              88.0
# 1     2021-11-28T10:19:23.324927+00:00              27.0
# 2     2021-11-28T10:19:23.332323+00:00              30.0
# 3     2021-11-28T10:19:23.338045+00:00              32.0
# 4     2021-11-28T10:19:23.226271+00:00              52.0
# ...                                ...               ...
# 9905  2021-11-28T12:19:18.690756+00:00              20.0
# 9906  2021-11-28T12:19:18.695274+00:00              39.0
# 9907  2021-11-28T12:19:18.699022+00:00              21.0
# 9908  2021-11-28T12:19:18.702711+00:00              34.0
# 9909  2021-11-28T12:19:18.706203+00:00              38.0
#
# [9809 rows x 10 columns]

# %% [markdown]
# Get the mean duration for all those rides

# %%
df.duration_minutes.mean()
# Out:
# 55.672137832602715
